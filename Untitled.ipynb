# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/clean_data.csv")

# %%
#plt.hist(df["outcome"], color = df["treatment"])

#df.hist(column='outcome', by = "treatment")

df.plot(kind='hist',
        alpha=0.7,
        bins=30,
        title='Histogram Of Test Scores',
        rot=45,
        grid=True,
        figsize=(12,8),
        fontsize=15, 
        color=['#A0E8AF', '#FFCF56'])
plt.xlabel('Test Score')
plt.ylabel("Number Of Students");
